# %%
class Node: 
  
    # Constructor to initialize the node object 
    def __init__(self, data): 
        self.data = data 
        self.next = None
  
class LinkedList: 
  
    # Function to initialize head 
    def __init__(self): 
        self.head = None
  
    # Function to reverse the linked list 
    def reverse(self): 
        prev = None
        current = self.head 
        while(current is not None): 
            next = current.next
            current.next = prev 
            prev = current 
            current = next
        self.head = prev 
          
    # Function to insert a new node at the beginning 
    def push(self, new_data): 
        new_node = Node(new_data) 
        new_node.next = self.head 
        self.head = new_node 
  
    # Utility function to print the linked LinkedList 
    def printList(self): 
        temp = self.head 
        while(temp): 
            print temp.data, 
            temp = temp.next
  
  
# Driver program to test above functions 
llist = LinkedList() 
llist.push(20) 
llist.push(4) 
llist.push(15) 
llist.push(85) 
  
print "Given Linked List"
llist.printList() 
llist.reverse() 
print "\nReversed Linked List"
llist.printList()

# %%
class Node: 
  
    # Constructor to initialize the node object 
    def __init__(self, data): 
        self.data = data 
        self.next = None
        
def reverse_linked_list(head):
    cur = head
    prev = None
    while cur is not None:
        next = cur.next
        cur.next = prev
        prev = cur
        cur = next
    head = prev
    return head
    
head = Node(0)
head.next = Node(1)
head.next.next = Node(2)
head.next.next.next = Node(3)

print(head.data)
print(head.next.data)
print(head.next.next.data)
print(head.next.next.next.data)

head = reverse_linked_list(head)
print(head.data)
print(head.next.data)
print(head.next.next.data)
print(head.next.next.next.data)
# Out:
# 0
# 1
# 2
# 3
# 3
# 2
# 1
# 0

# %%
#https://leetcode.com/problems/reorder-list/submissions/
    
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def reorderList(self, head):
        """
        :type head: ListNode
        :rtype: None Do not return anything, modify head in-place instead.
        """
        cur = head
        vec = []
        while cur is not None:
            vec.append(cur)
            cur = cur.next
        
        
        halfway = int(len(vec)/2)
        real_mid = int((len(vec) + 1)/2)
        vec_last = len(vec) -1
        
        even =False
        for idx in range(halfway):
            #print(vec_last -idx - idx, vec[idx].val, vec[vec_last - idx].val)

            cur = vec[idx]
            insert = vec[vec_last - idx]
            next_n =  cur.next
            cur.next = insert
            insert.next = next_n
            
        if(halfway < len(vec)):    
            vec[halfway].next = None

# %%
#https://leetcode.com/problems/subarray-product-less-than-k/solution/
    
class Solution(object):
    def numSubarrayProductLessThanK(self, nums, k):
        if k <= 1: return 0
        prod = 1
        ans = left = 0
        for right, val in enumerate(nums):
            prod *= val
            while prod >= k:
                prod /= nums[left]
                left += 1
            ans += right - left + 1
        return ans

# %%
#https://leetcode.com/problems/remove-duplicates-from-sorted-list-ii/   
li
    def deleteDuplicates(self, head: ListNode) -> ListNode:
        
        cur = head
        prev_l1 = None
        while cur is not None:
            val = cur.val
            next_node = cur.next
            
            prev_l2 = cur
            duplicate = False
            while next_node is not None:
                if val == next_node.val:
                    duplicate = True
                    if(prev_l2 is not None):
                        prev_l2.next = next_node.next
                    else:
                        head = head.next
                else:
                    prev_l2 = next_node
                next_node = next_node.next
                
            if duplicate == True:
                if(prev_l1 is not None):
                    prev_l1.next = cur.next
                else:
                    head = head.next
            else:
                prev_l1 = cur
                
            cur = cur.next
            
        return head

# %%
A = [5]*3
A
# Out:
# [5, 5, 5]
